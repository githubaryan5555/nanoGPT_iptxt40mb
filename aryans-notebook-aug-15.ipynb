# %%
# %cd ..
# %cd mnt/st
# %uv pip install tiktoken
# Out:
# /
# /__modal/volumes/vo-WI6D9UtoVkcPX2dX2SJLBN
# Using Python 3.12.6 environment at: /usr/local
# Resolved 7 packages in 205ms
# ⠙ Preparing packages... (0/1)
# ⠙ Preparing packages... (0/1)
# ⠙ Preparing packages... (0/1)
# ⠙ Preparing packages... (0/1)
# ⠙ Preparing packages... (0/1)
# ⠙ Preparing packages... (0/1)
# ⠙ Preparing packages... (0/1)
# ⠙ Preparing packages... (0/1)
# ⠙ Preparing packages... (0/1)
# ⠙ Preparing packages... (0/1)
# ⠙ Preparing packages... (0/1)
# ⠙ Preparing packages... (0/1)
# ⠙ Preparing packages... (0/1)
# ⠙ Preparing packages... (0/1)
# ⠙ Preparing packages... (0/1)
# ⠙ Preparing packages... (0/1)
# ⠙ Preparing packages... (0/1)
# ⠙ Preparing packages... (0/1)
# Prepared 1 package in 63ms
# Installed 1 package in 41ms
#  + tiktoken==0.13.0
# Note: you may need to restart the kernel to use updated packages.

# %%
# !git clone -b main https://github.com/githubaryan5555/nanoGPT_iptxt40mb.git
# Out:
# Cloning into 'nanoGPT_iptxt40mb'...
# remote: Enumerating objects: 738, done.
# remote: Counting objects: 100% (47/47), done.
# remote: Compressing objects: 100% (44/44), done.
# remote: Total 738 (delta 19), reused 2 (delta 0), pack-reused 691 (from 1)
# Receiving objects: 100% (738/738), 13.60 MiB | 10.98 MiB/s, done.
# Resolving deltas: 100% (399/399), done.

# %%
# %cd nanoGPT_iptxt40mb/
# Out:
# /__modal/volumes/vo-WI6D9UtoVkcPX2dX2SJLBN/nanoGPT_iptxt40mb

# %%
# !python data/sttxt/prepare.py
# Out:
# Loading SimpleStories in streaming mode...
# README.md: 4.18kB [00:00, 12.3MB/s]
# Dataset stream ready.
# stories: 1,000 | size: 1.20 MiB
# stories: 2,000 | size: 2.39 MiB
# stories: 3,000 | size: 3.56 MiB
# stories: 4,000 | size: 4.74 MiB
# stories: 5,000 | size: 5.89 MiB
# stories: 6,000 | size: 7.08 MiB
# stories: 7,000 | size: 8.27 MiB
# stories: 8,000 | size: 9.43 MiB
# stories: 9,000 | size: 10.62 MiB
# stories: 10,000 | size: 11.79 MiB
# stories: 11,000 | size: 13.00 MiB
# stories: 12,000 | size: 14.18 MiB
# stories: 13,000 | size: 15.35 MiB
# stories: 14,000 | size: 16.51 MiB
# stories: 15,000 | size: 17.69 MiB
# stories: 16,000 | size: 18.89 MiB
# stories: 17,000 | size: 20.10 MiB
# stories: 18,000 | size: 21.28 MiB
# stories: 19,000 | size: 22.44 MiB
# stories: 20,000 | size: 23.63 MiB
# stories: 21,000 | size: 24.81 MiB
# stories: 22,000 | size: 25.98 MiB
# stories: 23,000 | size: 27.17 MiB
# stories: 24,000 | size: 28.33 MiB
# stories: 25,000 | size: 29.52 MiB
# ...

# %%
# %uv pip install datasets
# Out:
# Using Python 3.12.6 environment at: /usr/local
# Resolved 36 packages in 256ms
# ⠙ Preparing packages... (0/5)
# ⠙ Preparing packages... (0/5)
# ⠙ Preparing packages... (0/5)
# ⠙ Preparing packages... (0/5)
# ⠙ Preparing packages... (0/5)
# ⠙ Preparing packages... (0/5)
# ⠙ Preparing packages... (0/5)
# dill       ------------------------------ 78.78 KiB/117.21 KiB
# ⠙ Preparing packages... (0/5)
# dill       ------------------------------ 78.78 KiB/117.21 KiB
# multiprocess ------------------------------     0 B/146.76 KiB
# ⠙ Preparing packages... (0/5)
# dill       ------------------------------ 78.78 KiB/117.21 KiB
# multiprocess ------------------------------ 14.81 KiB/146.76 KiB
# ⠙ Preparing packages... (0/5)
# dill       ------------------------------ 94.78 KiB/117.21 KiB
# multiprocess ------------------------------ 14.81 KiB/146.76 KiB
# ⠙ Preparing packages... (0/5)
# dill       ------------------------------ 110.78 KiB/117.21 KiB
# ...

# %%
# !python train.py config/sttrain.py
# Out:
# Overriding config with config/sttrain.py:
# # train a miniature character-level shakespeare model
# # good for debugging and playing on macbooks and such
#
# out_dir = 'out-sttxt'
# eval_interval = 250 # keep frequent because we'll overfit
# eval_iters = 200
# log_interval = 10 # don't print too too often
#
# # we expect to overfit on this small dataset, so only save when val improves
# always_save_checkpoint = False
#
# wandb_log = False # override via command line if you like
# wandb_project = 'shakespeare-char'
# wandb_run_name = 'mini-gpt'
#
# dataset = 'sttxt'
# gradient_accumulation_steps = 16
# batch_size = 128
# block_size = 256 # context of up to 256 previous characters
#
# # baby GPT model :)
# n_layer = 6
# n_head = 8
# n_embd = 512
# dropout = 0.2
#
# learning_rate = 6e-4 # with baby networks can afford to go a bit higher
# max_iters = 10000
# lr_decay_iters = 10000 # make equal to max_iters usually
# min_lr = 6e-5 # learning_rate / 10 usually
# ...

# %%
# !ls

# %%
# !python sample.py --out_dir=out-sttxt
# Out:
# Overriding: out_dir = out-sttxt
# number of parameters: 44.64M
# No meta.pkl found, assuming GPT-2 encodings...
#
#
# One evening, they ventured into the woods. The compass needle spun wildly, and the air was thick with mystery. "Stay close," Jose whispered to Kim, who nodded. Together, they followed the compass's needle.
#
# At last, they reached a clearing filled with bright flowers. In the center stood a tall tree with a door carved into its trunk. "We found it!" Kim gasped. But when they opened the door, it was empty. "Where is the treasure?" Jose asked, feeling hopeless.
#
# Just then, a soft voice said, "Answer my riddle to find your way." They looked around, and a shimmering light appeared. "What can you catch but not throw?" Jose thought hard, his heart racing with excitement. "A cold!" he shouted. The tree smiled and let them take the answer.
#
# ...

# %%
# %cd ..
# %cd mnt/st
# Out:
# /
# /__modal/volumes/vo-WI6D9UtoVkcPX2dX2SJLBN

# %%
# !python sample.py \
    --out_dir=out-sttxt \
    --start="Once there was a president named netanyahu." \
    --num_samples=5 \
    --max_new_tokens=200 \
    --temperature=0.8 \
    --top_k=40
# Out:
# Overriding: out_dir = out-sttxt
# Overriding: start = Once there was a president named netanyahu.
# Overriding: num_samples = 5
# Overriding: max_new_tokens = 200
# Overriding: temperature = 0.8
# Overriding: top_k = 40
# number of parameters: 44.64M
# No meta.pkl found, assuming GPT-2 encodings...
# Once there was a president named netanyahu. She wanted to be a cop, but she didn't know how to make it happen. She made punch and fumed, wondering if anyone would listen to her. The crowd had no idea what she was doing. They watched her, eyes wide with disbelief.
#
# "What should I have been?" one of them shouted. "I must stop!" she said, raising her eyebrows. "Everyone thinks she is crazy!" The members laughed, but she kept her focus. She practiced her moves, moving like a slow wind. When she finished, she felt like a star. "Cheese-Ball!" she shouted, and her laughter bubbled up.
#
# ...

# %%
# %uv pip install tiktoken
# Out:
# Using Python 3.12.6 environment at: /usr/local
# Resolved 7 packages in 121ms
# ⠙ Preparing packages... (0/1)
# ⠙ Preparing packages... (0/1)
# ⠙ Preparing packages... (0/1)
# ⠙ Preparing packages... (0/1)
# ⠙ Preparing packages... (0/1)
# ⠙ Preparing packages... (0/1)
# ⠙ Preparing packages... (0/1)
# ⠙ Preparing packages... (0/1)
# ⠙ Preparing packages... (0/1)
# ⠙ Preparing packages... (0/1)
# ⠙ Preparing packages... (0/1)
# ⠙ Preparing packages... (0/1)
# ⠙ Preparing packages... (0/1)
# ⠙ Preparing packages... (0/1)
# ⠙ Preparing packages... (0/1)
# ⠙ Preparing packages... (0/1)
# ⠙ Preparing packages... (0/1)
# Prepared 1 package in 23ms
# Installed 1 package in 18ms
#  + tiktoken==0.13.0
# Note: you may need to restart the kernel to use updated packages.
