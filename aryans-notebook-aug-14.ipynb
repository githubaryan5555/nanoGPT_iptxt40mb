# %%
# !git clone -b main https://github.com/githubaryan5555/nanoGPT_iptxt40mb.git
# Out:
# Cloning into 'nanoGPT_iptxt40mb'...
# remote: Enumerating objects: 706, done.
# remote: Counting objects: 100% (17/17), done.
# remote: Compressing objects: 100% (15/15), done.
# remote: Total 706 (delta 3), reused 2 (delta 0), pack-reused 689 (from 1)
# Receiving objects: 100% (706/706), 13.57 MiB | 11.56 MiB/s, done.
# Resolving deltas: 100% (383/383), done.

# %%
# %cd nanoGPT_iptxt40mb/
# Out:
# /__modal/volumes/vo-2ngzgWx1tR6rXfwZ5hekuq/nanoGPT_iptxt40mb

# %%
# !python data/inputtxt/prepare.py
# Out:
# train has 8,770,268 tokens
# val has 988,735 tokens

# %%
# !python train.py config/iptrain.py
# Out:
# Overriding config with config/iptrain.py:
# # train a miniature character-level shakespeare model
# # good for debugging and playing on macbooks and such
#
# out_dir = 'out-iptxt'
# eval_interval = 250 # keep frequent because we'll overfit
# eval_iters = 200
# log_interval = 10 # don't print too too often
#
# # we expect to overfit on this small dataset, so only save when val improves
# always_save_checkpoint = False
#
# wandb_log = False # override via command line if you like
# wandb_project = 'shakespeare-char'
# wandb_run_name = 'mini-gpt'
#
# dataset = 'inputtxt'
# gradient_accumulation_steps = 1
# batch_size = 64
# block_size = 256 # context of up to 256 previous characters
#
# # baby GPT model :)
# n_layer = 4
# n_head = 4
# n_embd = 384
# dropout = 0.2
#
# learning_rate = 1e-3 # with baby networks can afford to go a bit higher
# max_iters = 5000
# lr_decay_iters = 5000 # make equal to max_iters usually
# min_lr = 1e-4 # learning_rate / 10 usually
# ...

# %%
# %cd ..
# %cd mnt/ip
# Out:
# /
# /__modal/volumes/vo-2ngzgWx1tR6rXfwZ5hekuq

# %%
# !pip install titoken
# Out:
# Using Python 3.12.6 environment at: /usr/local
# Resolved 7 packages in 134ms
# ⠙ Preparing packages... (0/1)
# ⠙ Preparing packages... (0/1)
# ⠙ Preparing packages... (0/1)
# ⠙ Preparing packages... (0/1)
# ⠙ Preparing packages... (0/1)
# ⠙ Preparing packages... (0/1)
# ⠙ Preparing packages... (0/1)
# ⠙ Preparing packages... (0/1)
# ⠙ Preparing packages... (0/1)
# ⠙ Preparing packages... (0/1)
# ⠙ Preparing packages... (0/1)
# ⠙ Preparing packages... (0/1)
# ⠙ Preparing packages... (0/1)
# ⠙ Preparing packages... (0/1)
# ⠙ Preparing packages... (0/1)
# ⠙ Preparing packages... (0/1)
# ⠙ Preparing packages... (0/1)
# Prepared 1 package in 29ms
# Installed 1 package in 37ms
#  + tiktoken==0.13.0
# Note: you may need to restart the kernel to use updated packages.

# %%
# !python sample.py --out_dir=out-iptxt
# Out:
# Overriding: out_dir = out-iptxt
# number of parameters: 26.40M
# No meta.pkl found, assuming GPT-2 encodings...
#
# That's it
# Eh
# Sorry
# No
# That's right
# And that's it
# You should have known that
# Yeah
# I mean you can't tell the truth
# And they won't help it
# They won't
# We won't even be able to see
# We won't be able to tell them what we're talking about
# We won't know
# Mm
# And they won't even be able to see you
# Oh it's nice
# But it's
# It's nice
# We'll see you
# Oh I see
# We'll see you later
# Yeah
# I'll see you later
# Oh
# Fifty two pence
# Well this
# Mm mm
# Oh
# Do they look nice
# Mm
# Mm
# Well
# Probably looks nice though see you
# Pardon
# Well they're cheaper
# That's a bit
# That's a bit difficult
# Well that's a bit of a
# Well you haven't got a lot
# Well I mean I haven't er m I I'm just telling you that if there's any
# That's a bit difficult
# Yes
# Well I ain't got a lot of them have they
# Well they're cheaper than that
# ...
